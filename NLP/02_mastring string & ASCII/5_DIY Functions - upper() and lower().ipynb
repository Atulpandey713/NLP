# %%
txt = 'Hello, how are you?'

# %% [markdown]
# ## 1.Uppercase Function

# %%
def upper(txt):
    string = ''
    for char in txt:
        if(ord(char)>=97 and ord(char)<=122):
            
            string += chr(ord(char)-32)
        else:
            string += char
    return string

# %%
txt.upper()
# Out:
# 'HELLO, HOW ARE YOU?'

# %%
txt.lower()
# Out:
# 'hello, how are you?'
