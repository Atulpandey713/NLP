# %%
'A'
# Out:
# 'A'

# %%
print('A')
# Out:
# A

# %%
ord('A')
# Out:
# 65

# %%
ord('a')
# Out:
# 97

# %%
ord('}')
# Out:
# 125

# %%
name = "Atul pandey"

# %%
print([char for char in name])
print([ord(char) for char in name])
# Out:
# ['A', 't', 'u', 'l', ' ', 'p', 'a', 'n', 'd', 'e', 'y']
# [65, 116, 117, 108, 32, 112, 97, 110, 100, 101, 121]
