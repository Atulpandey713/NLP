# %%
import re

# %% [markdown]
# ### 1. search

# %%
srch = re.search('you', 'Hello, how are you?')

# %%
srch
# Out:
# <re.Match object; span=(15, 18), match='you'>

# %%
srch.span()
# Out:
# (15, 18)

# %%
srch.start()
# Out:
# 15

# %%
srch.end()
# Out:
# 18

# %% [markdown]
# ### 2.findall

# %%
a = 'Hello,how are area  are you?'
b = 'are'

len(re.findall(b, a))
# Out:
# 3

# %% [markdown]
# ### 3. finditer

# %%
for s in re.finditer('are', 'Hello,how are area  are you?'):
    print(s.span())
# Out:
# (10, 13)
# (14, 17)
# (20, 23)

# %% [markdown]
# ### 4. creating Regular Expression

# %%
txt = 'My telephone number is 834-4324-345'
pattern = '\d\d\d-\d\d\d\d-\d\d\d'
re.search(pattern, txt)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\abhis\AppData\Local\Temp\ipykernel_7928\1412296566.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern = '\d\d\d-\d\d\d\d-\d\d\d'
# <re.Match object; span=(23, 35), match='834-4324-345'>

# %%
txt = 'My telephone number is 834-4324-345'
pattern = '\d{3}-\d{4}-\d{3}'
re.search(pattern, txt)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\abhis\AppData\Local\Temp\ipykernel_7928\1118953208.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern = '\d{3}-\d{4}-\d{3}'
# <re.Match object; span=(23, 35), match='834-4324-345'>

# %%
txt = 'My telephone number is 834-4324-345'
pattern = '\d{3}-\d{4}-\d{3}'
re.search(pattern, txt).group()
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\abhis\AppData\Local\Temp\ipykernel_7928\1999656098.py:2: SyntaxWarning: invalid escape sequence '\d'
#   pattern = '\d{3}-\d{4}-\d{3}'
# '834-4324-345'
