# %%
import re

# %% [markdown]
# ### 1. finding pattern with specific ending

# %%
re.findall('at','The rat sat on the mat and attached by a cat')
# Out:
# ['at', 'at', 'at', 'at', 'at']

# %%
re.findall('.at','The rat sat on the mat and attached by a cat')
# Out:
# ['rat', 'sat', 'mat', ' at', 'cat']

# %% [markdown]
# ### 2. start and end pattern matching

# %%
re.findall('\d','4 is divisible by 2 not by 3')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\abhis\AppData\Local\Temp\ipykernel_18456\29429489.py:1: SyntaxWarning: invalid escape sequence '\d'
#   re.findall('\d','4 is divisible by 2 not by 3')
# ['4', '2', '3']

# %%
re.findall('\d$','4 is divisible by 2 not by 3')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\abhis\AppData\Local\Temp\ipykernel_18456\2225025640.py:1: SyntaxWarning: invalid escape sequence '\d'
#   re.findall('\d$','4 is divisible by 2 not by 3')
# ['3']

# %%
re.findall('^\d','4 is divisible by 2 not by 32')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\abhis\AppData\Local\Temp\ipykernel_18456\1566857953.py:1: SyntaxWarning: invalid escape sequence '\d'
#   re.findall('^\d','4 is divisible by 2 not by 32')
# ['4']

# %% [markdown]
# ### 3.Finding Capital Letters

# %%
re.findall('[A-Z]','Welcome to GFG')
# Out:
# ['W', 'G', 'F', 'G']

# %% [markdown]
# ### 4.FINDING SMALL LETTERS

# %%
re.findall('[a-z]','Welcome to GFG')
# Out:
# ['e', 'l', 'c', 'o', 'm', 'e', 't', 'o']

# %% [markdown]
# ### 5. finding uppercase , lowercase and numbers

# %%
re.findall('[A-Za-z]','Welcome to GFG')
# Out:
# ['W', 'e', 'l', 'c', 'o', 'm', 'e', 't', 'o', 'G', 'F', 'G']
