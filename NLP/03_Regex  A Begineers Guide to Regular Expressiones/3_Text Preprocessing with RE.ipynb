# %%
import re

# %% [markdown]
# ### 1 . Removing the Speical charector

# %%
txt = 'Eshant is ha%ppy! But, wh$y is h*e not playing?  '

# %%
''.join(re.findall('[^!$,%*?]+',txt))
# Out:
# 'Eshant is happy But why is he not playing  '

# %% [markdown]
# ### 2.Exclusion

# %%
txt = "I'm Atul and 24"
