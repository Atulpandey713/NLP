# %% [markdown]
# ### 1.Word finding

# %%
txt = 'AI is having the capability to revolutionize the industry '

word = 'the'.lower()

# %%
for i in range(len(txt)):
    if(txt[i:i+len(word)]==word):
        print(i,i+len(word))
# Out:
# 13 16
# 45 48
